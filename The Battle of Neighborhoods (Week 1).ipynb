# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# #### At the begining of 2020 a new virus called sars cov 2 was discovered in China (Wuhan). Since then many people died and several others have sequels related to this new virus, popularly known as Covid-19.
#
# #### As a measure to avoid more people dying and the economy of the world colapses due to the restriction policies, the whole world started to work togheter in search of a new vaccine.
#
# #### Considering that the vaccine will be available only in 2021 and not for all people, local governments are responsible for taking care of their own people putting into pratice restrictions to avoid crowding and also providing health care.
#
# #### In this article my intention is to present a simple analysis for choose strategic locations where the local government can invest with hospitals or medical care.

# %%
# In this article I'll use the data provided by Brazilian Government - specific for Rio Grand do Sul

link = 'https://ti.saude.rs.gov.br/covid19/'

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\William Roesch\Downloads\20201213.xlsx')
df.head()
# Out:
#    COD_IBGE MUNICIPIO  COD_REGIAO_COVID REGIAO_COVID       SEXO FAIXAETARIA  \
# 0    430003    ACEGUÁ                16   BAGE - R22   Feminino     40 a 49
# 1    430003    ACEGUÁ                16   BAGE - R22  Masculino     50 a 59
# 2    430003    ACEGUÁ                16   BAGE - R22   Feminino     20 a 29
# 3    430003    ACEGUÁ                16   BAGE - R22   Feminino     50 a 59
# 4    430003    ACEGUÁ                16   BAGE - R22   Feminino     20 a 29
#
#   CRITERIO DATA_CONFIRMACAO DATA_SINTOMAS DATA_EVOLUCAO  ...  \
# 0   RT-PCR       2020-10-05    2020-09-29           NaT  ...
# 1   RT-PCR       2020-11-23    2020-11-15           NaT  ...
# 2   RT-PCR       2020-09-11    2020-09-08           NaT  ...
# 3   RT-PCR       2020-11-26    2020-11-18    2020-12-01  ...
# 4   RT-PCR       2020-11-18    2020-11-15           NaT  ...
#
#   DATA_INCLUSAO_OBITO DATA_EVOLUCAO_ESTIMADA RACA_COR  ETNIA_INDIGENA  \
# ...

# %% [markdown]
# #### We will use 2 different datas: confirmed cases for each city and population of each city
#
# #### The data used is provided by state of Rio Grande do Sul government. In this dataset there are a lot of important variables that we can use to identify the best region to increase the atention in health care terms to achieve a smaller level of infected people. Also, with this dataset I want to understand and show how geographic distribution is being impacted by the virus and where we can suggest to to intensify medical care.
# #### The most important variables here are: MUNICIPIO, FAIXAETARIA, BAIRRO and DATA_CONFIRMACAO. All the occurences in this dataset are confirmed cases.

# %%
df2 = pd.read_excel(r'C:\Users\William Roesch\Downloads\e27f8577f6ae96db9f6707a1f7c3ee64.xlsx')
df2.head()
# Out:
#   Município [-]  Código [-]  Gentílico [-]        Prefeito [2017]  \
# 0        Aceguá   4300034.0     aceguaense        GERHARD MARTENS
# 1    Água Santa   4300059.0  água-santense         JACIR MIORANDO
# 2         Agudo   4300109.0       agudense   VALERIO VILI TREBIEN
# 3     Ajuricaba   4300208.0   ajuricabense            IVAN CHAGAS
# 4       Alecrim   4300307.0    alecrinense  LEONEL EGIDIO COLOSSI
#
#    Área Territorial - km² [2019]  População estimada - pessoas [2020]  \
# 0                       1551.339                               4942.0
# 1                        291.503                               3743.0
# 2                        534.624                              16401.0
# 3                        322.699                               6987.0
# 4                        316.394                               5827.0
#
#   Densidade demográfica - hab/km² [2010]  \
# 0                                   2.84
# 1                                  12.76
# ...
